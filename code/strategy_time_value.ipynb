# %%
from importnb import Notebook
with Notebook():
    import cleaning as cd

# %%
data_base_merged=cd.data_base_merged

# %%
data_base_merged
# Out:
#                      biof_fecha  bi_1_precio  bi_1_size  of_1_precio  \
# 2       2025-05-05 14:00:12.307        27.50      100.0         30.0
# 4       2025-05-05 14:00:12.808         5.01      100.0         30.0
# 5       2025-05-05 14:00:12.926         5.01      100.0         30.0
# 7       2025-05-05 14:00:14.498         5.01      100.0         27.5
# 9       2025-05-05 14:00:16.492         5.01      100.0         27.5
# ...                         ...          ...        ...          ...
# 1044487 2025-05-05 19:59:35.484      1750.00       50.0       1945.0
# 1044491 2025-05-05 19:59:37.809      1750.00       50.0       1945.0
# 1044492 2025-05-05 19:59:38.310      1750.00       50.0       1945.0
# 1044503 2025-05-05 19:59:49.846      1750.00       50.0       1945.0
# 1044513 2025-05-05 19:59:58.511      1750.00       50.0       1945.0
#
#          of_1_size         ultimo_fecha  bi_1_precio_under  bi_1_size_under  \
# ...

# %%
strategy = data_base_merged[data_base_merged["time_value"]<0]

# %%
strategy

# %%
strategy=strategy[strategy["id_simbolo"]=="MERV - XMEV - GFGV7800JU - 24hs"]

# %%
strategy
# Out:
# Empty DataFrame
# Columns: [biof_fecha, bi_1_precio, bi_1_size, of_1_precio, of_1_size, ultimo_fecha, bi_1_precio_under, bi_1_size_under, of_1_precio_under, of_1_size_under, ultimo_fecha_under, id_simbolo, changed_opt, changed_und, trade_opt, trade_und, event, instrument, strike, intrinsic_value, time_value]
# Index: []
#
# [0 rows x 21 columns]
